# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'white'

# %%
data = pd.read_csv("/Users/benhoskings/Library/CloudStorage/OneDrive-UniversityofWarwick/Documents/Engineering/Year 4/HERO/Data/consultation_record.tsv")

# %%
data.loc[len(data.index)] = {"User_ID": 0, "Date": "20",
                "PSS_Score": 7,
                "Wisconsin_Card_Score": None}

data.head()
# Out:
#   Consult_ID\tUser_ID\tDate\tPSS_Score\tWisconsin_Card_Score
# 0              l25t9fvasgp37hy\t0\t2023-12-11\t0.0\t
# 1              mh6wntq5vuy348f\t0\t2023-12-11\t0.0\t
# 2              06c1gja4qnoebr3\t0\t2023-12-31\t9.0\t
# 3             yh6lt8fkbdv139n\t0\t2024-01-07\t13.0\t
# 4             c32mwjdb9fh5xl6\t0\t2024-01-17\t15.0\t

# %%
np.arctan2(1, 2) * 180 / np.pi # given as y, x
# Out:
# 26.56505117707799

# %%
user_data = pd.read_csv("spiral_data_user.csv")
ref_data = pd.read_csv("spiral_data_ref.csv")

# %%
plt.plot(user_data["theta"], np.linalg.norm(user_data[["rel_pos_x", "rel_pos_y"]].to_numpy(), axis=1))
plt.plot(ref_data["theta"], ref_data["mag"])
plt.title("Spiral Analysis")
plt.xlabel("Theta")
plt.ylabel("Distance")
plt.savefig('spiral_analysis.png')
plt.show()

# %%
import requests
import json

# headers={'Authorization': 'Bearer ' + Access_Token}
response = requests.get(f'https://livewarwickac-my.sharepoint.com/:f:/g/personal/u2026405_live_warwick_ac_uk/EhHIDMGG8-JKsSO62TqO-BIB4bKC5BbyFeNKo2P78NSwEw?e=hO6jqy/children')
print(response.content)
content = json.loads(response.content)
for file in content.values:
    ...
    # file_response = requests.get(f'/drives/{drive-id}/root:/New Folder/{file.name}/content')
    # with open(file.name, 'wb') as dest_file:
    #     dest_file.write(file_response.content)
# Out:
# b'\r\n<!DOCTYPE html>\r\n<html lang="en-us" dir="ltr" class="ms-isBot">\r\n<head><meta name="GENERATOR" content="Microsoft SharePoint" /><meta http-equiv="Content-type" content="text/html; charset=utf-8" /><meta http-equiv="X-UA-Compatible" content="IE=edge" /><meta http-equiv="Expires" content="0" /><meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" /><title>\r\n\tOneDrive\r\n</title><link rel="shortcut icon" href="/_layouts/15/images/odbfavicon.ico?rev=47" type="image/vnd.microsoft.icon" id="favicon" /></head>\r\n <body style="margin: 0; padding: 0;">\r\n  <script  nonce= \'23707ecb-2529-4b0c-9eda-d6ed4663c402\' >if(!spfxPerfMarks){var spfxPerfMarks = {};} var markPerfStage=function(key) {if(window.performance && typeof window.performance.now === \'function\'){spfxPerfMarks[key]=window.performance.now();} else{spfxPerfMarks[key]=Date.now();} if (window.performance && typeof window.performance.mark === \'func
# ...
